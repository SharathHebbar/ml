# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading data

# %%
data = pd.read_csv("employee.csv")

# %%
data.head()
# Out:
#    Employee_id Gender    Remarks
# 0           45      M       nice
# 1           46      F       good
# 2           47      M      great
# 3           48      F  excellent
# 4           49      M        bad

# %% [markdown]
# ## Checking the labels in the column

# %%
data['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
data['Remarks'].unique()
# Out:
# array(['nice', 'good', 'great', 'excellent', 'bad'], dtype=object)

# %% [markdown]
# ## Checking count of each column

# %%
data['Gender'].value_counts()
# Out:
# M    22
# F    21
# Name: Gender, dtype: int64

# %%
data['Remarks'].value_counts()
# Out:
# nice         9
# good         9
# great        9
# excellent    8
# bad          8
# Name: Remarks, dtype: int64

# %% [markdown]
# ## Approach 1: Label Encoding

# %% [markdown]
# ##### label encoder encodes labels with value between 0 and number_of_class-1

# %% [markdown]
# ##### Categorical data to numeric form

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder_x = LabelEncoder()

# %%
label_encoded_data = label_encoder_x.fit_transform(data['Remarks'])

# %%
label_encoded_data = pd.DataFrame(data = label_encoded_data, columns = ['Remarks'])

# %%
label_encoded_data
# Out:
#     Remarks
# 0         4
# 1         2
# 2         3
# 3         1
# 4         0
# 5         4
# 6         2
# 7         3
# 8         1
# 9         0
# 10        4
# 11        2
# 12        3
# 13        1
# 14        0
# 15        4
# 16        2
# 17        3
# 18        1
# 19        0
# 20        4
# 21        2
# 22        3
# 23        1
# 24        0
# 25        4
# 26        2
# 27        3
# 28        1
# 29        0
# 30        4
# 31        2
# 32        3
# 33        1
# 34        0
# 35        4
# 36        2
# 37        3
# 38        1
# 39        0
# 40        4
# 41        2
# 42        3

# %%
label_encoded_data['Remarks'].unique()
# Out:
# array([4, 2, 3, 1, 0])

# %% [markdown]
# ## Approach 2: One Hot Encoding

# %% [markdown]
# ##### Binary labeling with 1 at position where the label is present else 0

# %%
one_hot_encode = pd.get_dummies(data,columns = ['Remarks','Gender'])

# %%
one_hot_encode
# Out:
#     Employee_id  Remarks_bad  Remarks_excellent  Remarks_good  Remarks_great  \
# 0            45            0                  0             0              0
# 1            46            0                  0             1              0
# 2            47            0                  0             0              1
# 3            48            0                  1             0              0
# 4            49            1                  0             0              0
# 5            50            0                  0             0              0
# 6            51            0                  0             1              0
# 7            52            0                  0             0              1
# 8            53            0                  1             0              0
# 9            54            1                  0             0              0
# 10           55            0                  0             0              0
# ...
