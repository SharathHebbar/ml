# %% [markdown]
# ### Grayscaling

# %% [markdown]
# Grayscaling is process by which an image is converted from a full color to shades of grey (black & white)
# In OpenCV, many functions grayscale images before processing. This is done because it simplifies the image, acting almost as a noise reduction and increasing processing time as there is less information in the image.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('road.jpg')
image
# Out:
# array([[[153,  99,  88],
#         [153,  99,  88],
#         [153,  99,  88],
#         ...,
#         [183, 167, 201],
#         [183, 167, 201],
#         [183, 167, 201]],
#
#        [[152,  98,  87],
#         [152,  98,  87],
#         [152,  98,  87],
#         ...,
#         [182, 166, 200],
#         [182, 166, 200],
#         [182, 166, 200]],
#
#        [[151,  97,  86],
#         [151,  97,  86],
#         [151,  97,  86],
#         ...,
#         [182, 165, 198],
#         [182, 165, 198],
#         [182, 165, 198]],
#
#        ...,
#
#        [[ 66,  49,  52],
#         [ 65,  51,  53],
#         [ 68,  51,  55],
#         ...,
#         [ 72,  89, 132],
#         [ 71,  88, 131],
#         [ 71,  88, 131]],
#
#        [[ 66,  50,  51],
#         [ 67,  51,  52],
#         [ 68,  51,  54],
#         ...,
#         [ 72,  89, 132],
#         [ 71,  88, 131],
#         [ 71,  88, 131]],
#
#        [[ 66,  50,  51],
#         [ 67,  51,  52],
#         [ 68,  51,  54],
#         ...,
#         [ 72,  89, 132],
#         [ 71,  88, 131],
#         [ 71,  88, 131]]], dtype=uint8)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[102, 102, 102, ..., 179, 179, 179],
#        [101, 101, 101, ..., 178, 178, 178],
#        [100, 100, 100, ..., 177, 177, 177],
#        ...,
#        [ 52,  53,  54, ..., 100,  99,  99],
#        [ 52,  53,  54, ..., 100,  99,  99],
#        [ 52,  53,  54, ..., 100,  99,  99]], dtype=uint8)

# %%
row , col = 1, 2
fig,axes = plt.subplots(row, col, figsize = (15,10))
fig.tight_layout()

axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[0].set_title('Original')
axes[1].imshow(cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB))
axes[1].set_title('Grayscale')
# Out:
# Text(0.5, 1.0, 'Grayscale')

# %%
cv2.imwrite('grayscale.jpg',gray_image)
cv2.imwrite('grayscale.png',gray_image)
# Out:
# True
