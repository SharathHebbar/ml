# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
inp = cv2.imread('road.jpg')

# %%
plt.imshow(cv2.cvtColor(inp,cv2.COLOR_BGR2RGB))
plt.show()

# %%
print(inp.shape)
# Out:
# (1603, 2400, 3)

# %%
print("height ", inp.shape[0], " in pixels")
print("width ", inp.shape[1], " in pixels")
# Out:
# height  1603  in pixels
# width  2400  in pixels

# %% [markdown]
# ### Saving images

# %%
cv2.imwrite('roadop.png',inp)
cv2.imwrite('roadop.jpg',inp)
# Out:
# True
