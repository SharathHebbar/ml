# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading data and data exploration

# %%
data = pd.read_csv("house.csv")
data.head()
# Out:
#    latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0   -122.23      37.88                  41          880             129
# 1   -122.24      37.89                  28         1233             300
# 2   -122.25      37.90                  36         1586             471
# 3   -122.26      37.91                  42         1939             642
# 4   -122.27      37.92                  29         2292             813
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         125           8.30              452600        Near Bay
# 1         500         177           7.25              350000        Near Bay
# 2         678         229           8.54              380000        Near Bay
# 3         856         281           7.70              452601        Near Bay
# 4        1034         333           9.30              350001        Near Bay

# %%
data.describe()
# Out:
#          latitude  longitude  housing_median_age   total_rooms  \
# count   87.000000  87.000000           87.000000     87.000000
# mean  -122.660000  38.310000           49.000000  16059.000000
# std      0.252587   0.252587            9.990693   8916.307644
# min   -123.090000  37.880000           28.000000    880.000000
# 25%   -122.875000  38.095000           42.000000   8469.500000
# 50%   -122.660000  38.310000           49.000000  16059.000000
# 75%   -122.445000  38.525000           56.000000  23648.500000
# max   -122.230000  38.740000           69.000000  31238.000000
#
#        total_bedrooms    population   households  median_income  \
# count       87.000000     87.000000    87.000000      87.000000
# mean      7482.000000   7976.000000  2361.000000      18.329655
# std       4319.231182   4496.041815  1313.450418       6.341251
# min        129.000000    322.000000   125.000000       7.250000
# 25%       3805.500000   4149.000000  1243.000000      12.975000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   latitude            87 non-null     float64
#  1   longitude           87 non-null     float64
#  2   housing_median_age  87 non-null     int64
#  3   total_rooms         87 non-null     int64
#  4   total_bedrooms      87 non-null     int64
#  5   population          87 non-null     int64
#  6   households          87 non-null     int64
#  7   median_income       87 non-null     float64
#  8   median_house_value  87 non-null     int64
#  9   ocean_proximity     87 non-null     object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 6.9+ KB

# %%
#filling null values
#data = data.fillna()
#data = data.drop(['ocean_proximity'],axis = 1)
data
# Out:
#     latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23      37.88                  41          880             129
# 1    -122.24      37.89                  28         1233             300
# 2    -122.25      37.90                  36         1586             471
# 3    -122.26      37.91                  42         1939             642
# 4    -122.27      37.92                  29         2292             813
# ..       ...        ...                 ...          ...             ...
# 82   -123.05      38.70                  55        29826           14151
# 83   -123.06      38.71                  63        30179           14322
# 84   -123.07      38.72                  69        30532           14493
# 85   -123.08      38.73                  56        30885           14664
# 86   -123.09      38.74                  64        31238           14835
#
#     population  households  median_income  median_house_value ocean_proximity
# ...

# %% [markdown]
# ## Approach 1 Manual splitting

# %% [markdown]
# #### Splitting data into input and output

# %%
x = data.drop(['median_house_value'],axis=1)
x.head()
# Out:
#    latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0   -122.23      37.88                  41          880             129
# 1   -122.24      37.89                  28         1233             300
# 2   -122.25      37.90                  36         1586             471
# 3   -122.26      37.91                  42         1939             642
# 4   -122.27      37.92                  29         2292             813
#
#    population  households  median_income ocean_proximity
# 0         322         125           8.30        Near Bay
# 1         500         177           7.25        Near Bay
# 2         678         229           8.54        Near Bay
# 3         856         281           7.70        Near Bay
# 4        1034         333           9.30        Near Bay

# %%
x.shape
# Out:
# (87, 9)

# %%
y = data['median_house_value']
y
# Out:
# 0     452600
# 1     350000
# 2     380000
# 3     452601
# 4     350001
#        ...
# 82    350027
# 83    380027
# 84    452628
# 85    350028
# 86    380028
# Name: median_house_value, Length: 87, dtype: int64

# %%
y.shape
# Out:
# (87,)

# %% [markdown]
# ##### splitting input n output to training and testing the data

# %%
x_train, x_test = x.loc[0:70],x.loc[70:]
y_train, y_test = y.loc[0:70],y.loc[70:]
print(x_train,x_test,y_train,y_test)
# Out:
#     latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23      37.88                  41          880             129
# 1    -122.24      37.89                  28         1233             300
# 2    -122.25      37.90                  36         1586             471
# 3    -122.26      37.91                  42         1939             642
# 4    -122.27      37.92                  29         2292             813
# ..       ...        ...                 ...          ...             ...
# 66   -122.89      38.54                  63        24178           11415
# 67   -122.90      38.55                  50        24531           11586
# 68   -122.91      38.56                  58        24884           11757
# 69   -122.92      38.57                  64        25237           11928
# 70   -122.93      38.58                  51        25590           12099
#
#     population  households  median_income ocean_proximity
# ...

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (71, 9)
# (17, 9)
# (71,)
# (17,)

# %% [markdown]
# ## Splitting using sklearn

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (69, 9)
# (18, 9)
# (69,)
# (18,)

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#     latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 4    -122.27      37.92                  29         2292             813
# 16   -122.39      38.04                  33         6528            2865
# 79   -123.02      38.67                  54        28767           13638
# 7    -122.30      37.95                  30         3351            1326
# 28   -122.51      38.16                  37        10764            4917
# ..       ...        ...                 ...          ...             ...
# 30   -122.53      38.18                  51        11470            5259
# 19   -122.42      38.07                  34         7587            3378
# 15   -122.38      38.03                  46         6175            2694
# 34   -122.57      38.22                  39        12882            5943
# 40   -122.63      38.28                  41        15000            6969
#
#     population  households  median_income ocean_proximity
# ...
